# %%
#!pip install python-dotenv
#!pip install openai
#!pip install imageio
#!pip install azure-ai-documentintelligence
#!pip install azure-core

# %%
from openai import AzureOpenAI
import dotenv
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult, AnalyzeDocumentRequest
import json

dotenv.load_dotenv(override=True)
# Out:
# True

# %%
client = AzureOpenAI(
    azure_endpoint=os.getenv('AzureOpenAiEndpoint'),
    api_key=os.getenv('AzureOpenAiKey'),
    azure_deployment='gpt-4o',
    api_version='2024-02-15-preview'
)

# %%
documentIntelligenceClient = DocumentIntelligenceClient(
        credential=AzureKeyCredential(key=os.getenv('AzureDiKey')),
        endpoint=os.getenv('AzureDiEndpoint')
        )

# %%
def analyze_document(file):
    poller = documentIntelligenceClient.begin_analyze_document(
            "prebuilt-layout", AnalyzeDocumentRequest(
                bytes_source=file,
            ),output_content_format="markdown"
    )
    return poller.result()

# %%
def split_document_to_pages(document):
    totalPages = document['pages']
    documentContent = []
    for page in totalPages:
        pageContent = {
            "pageNumber": page['pageNumber'],
            "pageContent": ' '.join([pageLineContent.content for pageLineContent in page.lines if pageLineContent is not None])
        }
        documentContent.append(pageContent.copy())
    return documentContent

# %%
def document_ask(prompt,analyzedDocumentContent):
    response =client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {
                'role': 'user',
                'content': prompt
            },
            {
                'role': 'system',
                'content': f'You know about this file: {analyzedDocumentContent}'
            }
        ]
    )
    return response.choices[0].message.content

# %% [markdown]
# ### MSFT Report

# %%
with open("msft.pdf", "rb") as f:
    msft_file = f.read()

# %%
msft_file
# Out:
# b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n<</Type/Catalog/Pages 2 0 R/Lang(de) /StructTreeRoot 31 0 R/MarkInfo<</Marked true>>/Metadata 2999 0 R/ViewerPreferences 3000 0 R>>\r\nendobj\r\n2 0 obj\r\n<</Type/Pages/Count 1/Kids[ 4 0 R] >>\r\nendobj\r\n3 0 obj\r\n<</MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_Enabled(true) /MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_Method(Standard) /MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_SiteId(72f988bf-86f1-41af-91ab-2d7cd011db47) /MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_ContentBits(0) /Producer(\xfe\xff\x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00\xae\x00 \x00W\x00o\x00r\x00d\x00 \x00f\x00o\x00r\x00 \x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00 \x003\x006\x005) /Creator(\xfe\xff\x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00\xae\x00 \x00W\x00o\x00r\x00d\x00 \x00f\x00o\x00r\x00 \x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00 \x003\x006\x005) /CreationDate(D:20240712123751+02\'00\') /ModDate(D:20240712123751+02\'00\') >>\r\nendobj\r\n4 0 obj\r\n<</Type/Page/Parent 2 0 R/Resources<</Font<</F1 6 0 R/F2 10 0 R/F3 15 0 R/F4 17 0 R/F5 19 0 R/F6 24 0 R/F7 26 0 R>>/ExtGState<</GS8 8 0 
# %%
document_ask("Provide the exact number of recorded basis for equity investments of level 1 in 2023.",msft_file_per_page)
# Out:
# 'The recorded basis for Level 1 equity investments in 2023 is $2,692 million.'

# %%
document_ask("Provide the exact number of recorded basis for equity investments of level 1 in 2022.",msft_file_per_page)
# Out:
# 'For the year ending June 30, 2022, the recorded basis for Level 1 equity investments was $456 million.'

# %%
document_ask("Provide the recorded basis for Corporate notes and bonds of Level 3 in 2023.",msft_file_per_page)
# Out:
# 'The recorded basis for Corporate notes and bonds of Level 3 in 2023 is $120 million.'

# %%
document_ask("Provide the recorded basis for Corporate notes and bonds of Level 3 in 2022.",msft_file_per_page)
# Out:
# "As of June 30, 2022, the recorded basis for Corporate notes and bonds classified as Level 3 investments was $67 million. There were no adjusted unrealized gains or losses associated with these investments.\n\nHere's a summary for quick reference:\n\n- **Corporate notes and bonds (Level 3) in 2022:**\n  - Fair Value Level: Level 3\n  - Adjusted Unrealized Gains: $0\n  - Adjusted Unrealized Losses: $0\n  - Recorded Basis: $67 million"

# %%
document_ask("Provide the total number for unrealized gains of total debt investments for 2023 and 2022",msft_file_per_page)
# Out:
# 'Based on the provided content, the unrealized gains for total debt investments can be summarized for 2023 and 2022 as follows:\n\nFor the year ending June 30, 2023:\n- Total unrealized gains for debt investments: \\( \\$13 \\) million.\n\nFor the year ending June 30, 2022:\n- Total unrealized gains for debt investments: \\( \\$53 \\) million.\n\nTherefore, the total unrealized gains for total debt investments are \\( \\$13 \\) million for 2023 and \\( \\$53 \\) million for 2022.'

# %% [markdown]
# **Extra-curriculum:**

# %%
table = msft_file_analyzed.tables

# %%
table
# Out:
# [{'rowCount': 22, 'columnCount': 9, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': '(In millions)', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.4137, 1.294, 2.0871, 1.294, 2.0871, 1.7066, 0.4137, 1.7066]}], 'spans': [{'offset': 102, 'length': 13}], 'elements': ['/paragraphs/3']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': 'Fair Value Level', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0871, 1.294, 2.7876, 1.294, 2.7876, 1.7066, 2.0871, 1.7066]}], 'spans': [{'offset': 118, 'length': 16}], 'elements': ['/paragraphs/4']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': 'Adjusted\nCost Basis', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7876, 1.294, 3.5114, 1.294, 3.5114, 1.7066, 2.7876, 1.7066]}], 'spans': [{'offset': 138, 'length': 8}, {'offset': 158, 'length': 10}], 'elements': ['/paragraphs/5']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': 'Unrealized\nGains', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.5114, 1.294, 4.2041, 1.294, 4.2041, 1.7066, 3.5114, 1.7066]}], 'spans': [{'offset': 147, 'length': 10}, {'offset': 170, 'length': 5}], 'elements': ['/paragraphs/6']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': 'Unrealized Losses', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.2041, 1.294, 4.9357, 1.294, 4.9357, 1.7066, 4.2041, 1.7066]}], 'spans': [{'offset': 178, 'length': 17}], 'elements': ['/paragraphs/7']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 5, 'content': 'Recorded Basis', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9357, 1.294, 5.7296, 1.294, 5.7296, 1.7066, 4.9357, 1.7066]}], 'spans': [{'offset': 198, 'length': 14}], 'elements': ['/paragraphs/8']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 6, 'content': 'Cash and Cash\nEquivalents', 'boundingRegions': [{'pageNumber': 1, 'polygon': [5.7296, 1.294, 6.5001, 1.294, 6.5001, 1.7066, 5.7296, 1.7066]}], 'spans': [{'offset': 215, 'length': 13}, {'offset': 231, 'length': 11}], 'elements': ['/paragraphs/9']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 7, 'content': 'Investments\nShort-term', 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.5001, 1.294, 7.2629, 1.294, 7.2551, 1.7066, 6.5001, 1.7066]}], 'spans': [{'offset': 243, 'length': 11}, {'offset': 268, 'length': 10}], 'elements': ['/paragraphs/10']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 8, 'content': 'Investments\nEquity', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.2629, 1.294, 8.0412, 1.294, 8.0412, 1.7066, 7.2551, 1.7066]}], 'spans': [{'offset': 255, 'length': 11}, {'offset': 280, 'length': 6}], 'elements': ['/paragraphs/11']}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'June 30, 2023', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.4137, 1.7066, 2.0871, 1.7066, 2.0871, 1.9636, 0.4137, 1.9636]}], 'spans': [{'offset': 329, 'length': 13}], 'elements': ['/paragraphs/12']}, {'rowIndex': 1, 'columnIndex': 1, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0871, 1.7066, 2.7876, 1.7066, 2.7876, 1.9636, 2.0871, 1.9636]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 2, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7876, 1.7066, 3.5114, 1.7066, 3.5114, 1.9636, 2.7876, 1.9636]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 3, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.5114, 1.7066, 4.2041, 1.7066, 4.2041, 1.9636, 3.5114, 1.9636]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 4, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.2041, 1.7066, 4.9357, 1.7066, 4.9357, 1.9636, 4.2041, 1.9636]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 5, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9357, 1.7066, 5.7296, 1.7066, 5.7296, 1.9636, 4.9357, 1.9636]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 6, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [5.7296, 1.7066, 6.5001,  ...
#  {'rowCount': 21, 'columnCount': 9, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': '(In millions)', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.426, 5.6125, 2.0974, 5.6125, 2.0896, 6.0397, 0.426, 6.0397]}], 'spans': [{'offset': 1815, 'length': 13}], 'elements': ['/paragraphs/145']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': 'Fair Value Level', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0974, 5.6125, 2.7815, 5.6125, 2.7815, 6.0474, 2.0896, 6.0397]}], 'spans': [{'offset': 1831, 'length': 16}], 'elements': ['/paragraphs/146']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': 'Adjusted\nCost Basis', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7815, 5.6125, 3.5122, 5.6125, 3.5122, 6.0474, 2.7815, 6.0474]}], 'spans': [{'offset': 1851, 'length': 8}, {'offset': 1871, 'length': 10}], 'elements': ['/paragraphs/147']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': 'Unrealized\nGains', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.5122, 5.6125, 4.2041, 5.6125, 4.1963, 6.0474, 3.5122, 6.0474]}], 'spans': [{'offset': 1860, 'length': 10}, {'offset': 1883, 'length': 5}], 'elements': ['/paragraphs/148']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': 'Unrealized Losses', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.2041, 5.6125, 4.9348, 5.6125, 4.9348, 6.0474, 4.1963, 6.0474]}], 'spans': [{'offset': 1891, 'length': 17}], 'elements': ['/paragraphs/149']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 5, 'content': 'Recorded Basis', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9348, 5.6125, 5.7277, 5.6125, 5.7277, 6.0474, 4.9348, 6.0474]}], 'spans': [{'offset': 1911, 'length': 14}], 'elements': ['/paragraphs/150']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 6, 'content': 'Cash and Cash\nEquivalents', 'boundingRegions': [{'pageNumber': 1, 'polygon': [5.7277, 5.6125, 6.4974, 5.6125, 6.4974, 6.0397, 5.7277, 6.0474]}], 'spans': [{'offset': 1928, 'length': 13}, {'offset': 1944, 'length': 11}], 'elements': ['/paragraphs/151']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 7, 'content': 'Investments\nShort-term', 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.4974, 5.6125, 7.2592, 5.6125, 7.2592, 6.0397, 6.4974, 6.0397]}], 'spans': [{'offset': 1956, 'length': 11}, {'offset': 1981, 'length': 10}], 'elements': ['/paragraphs/152']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 8, 'content': 'Investments\nEquity', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.2592, 5.6125, 8.0443, 5.6125, 8.0443, 6.0397, 7.2592, 6.0397]}], 'spans': [{'offset': 1968, 'length': 11}, {'offset': 1993, 'length': 6}], 'elements': ['/paragraphs/153']}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'June 30, 2022', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.426, 6.0397, 2.0896, 6.0397, 2.0896, 6.2882, 0.426, 6.2882]}], 'spans': [{'offset': 2042, 'length': 13}], 'elements': ['/paragraphs/154']}, {'rowIndex': 1, 'columnIndex': 1, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0896, 6.0397, 2.7815, 6.0474, 2.7815, 6.2882, 2.0896, 6.2882]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 2, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7815, 6.0474, 3.5122, 6.0474, 3.5122, 6.2882, 2.7815, 6.2882]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 3, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.5122, 6.0474, 4.1963, 6.0474, 4.1963, 6.2882, 3.5122, 6.2882]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 4, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.1963, 6.0474, 4.9348, 6.0474, 4.9348, 6.2882, 4.1963, 6.2882]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 5, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9348, 6.0474, 5.7277, 6.0474, 5.7277, 6.2882, 4.9348, 6.2882]}], 'spans': []}, {'rowIndex': 1, 'columnIndex': 6, 'content': '', 'boundingRegions': [{'pageNu ...

# %%
document_ask("Provide the exact number of recorded basis for equity investments of level 1 in 2023.",table)
# Out:
# 'The exact number of recorded basis for equity investments of Level 1 in 2023 is \\$10,138 million.'

# %%
document_ask("Provide the exact number of recorded basis for equity investments of level 1 in 2022.",table)
# Out:
# 'The exact number of recorded bases for equity investments classified as Level 1 in 2022 is 1,590 (expressed in millions of dollars).\n\nThis information can be found in the provided table, specifically in the row labeled "Equity investments" under the "Changes in Fair Value Recorded in Net Income" section and the "Level 1" column for June 30, 2022.'

# %%
document_ask("Provide the recorded basis for Corporate notes and bonds of Level 3 in 2023.",table)
# Out:
# 'In 2023, the recorded basis for "Corporate notes and bonds" classified under Level 3 was $120 million.'

# %%
document_ask("Provide the recorded basis for Corporate notes and bonds of Level 3 in 2022.",table)
# Out:
# 'In 2022, the recorded basis for Corporate notes and bonds of Level 3 was $120 million.'

# %%
document_ask("Provide the total number for unrealized gains of total debt investments for 2023 and 2022",table)
# Out:
# 'The specific unrealized gains for total debt investments for the years 2023 and 2022 are as follows:\n\n- **2023:**\n  - Unrealized Gains: \\$13 million\n\n- **2022:**\n  - Unrealized Gains: \\$53 million\n\nThis data can be found in the "Unrealized Gains" column for "Total debt investments" in the respective years of the provided table.'
