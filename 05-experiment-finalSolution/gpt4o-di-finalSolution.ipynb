# %%
#!pip install python-dotenv
#!pip install openai
#!pip install imageio
#!pip install azure-ai-documentintelligence
#!pip install azure-core
#!pip install pymupdf

# %%
from openai import AzureOpenAI
import dotenv
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeDocumentRequest
import base64
import fitz
import io
from PIL import Image
dotenv.load_dotenv(override=True)
# Out:
# True

# %%
client = AzureOpenAI(
    azure_endpoint=os.getenv('AzureOpenAiEndpoint'),
    api_key=os.getenv('AzureOpenAiKey'),
    azure_deployment='gpt-4o',
    api_version='2024-02-15-preview'
)

# %%
documentIntelligenceClient = DocumentIntelligenceClient(
        credential=AzureKeyCredential(key=os.getenv('AzureDiKey')),
        endpoint=os.getenv('AzureDiEndpoint')
        )

# %%
def analyze_document(file):
    poller = documentIntelligenceClient.begin_analyze_document(
            "prebuilt-layout", AnalyzeDocumentRequest(
                bytes_source=file,
            ),output_content_format="markdown"
    )
    return poller.result()

# %%
def split_document_to_pages(document):
    totalPages = document['pages']
    documentContent = []
    for page in totalPages:
        pageContent = {
            "pageNumber": page['pageNumber'],
            "pageContent": ' '.join([pageLineContent.content for pageLineContent in page.lines if pageLineContent is not None]),
            "identifier": None
        }
        documentContent.append(pageContent.copy())
    return documentContent

# %%
def document_ask(prompt,analyzedDocumentContent):
    response =client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {
                'role': 'user',
                'content': f"Answer the question based only on the following context, which can include text, tables, and the below image. The question: {prompt}"
            },
            {
                'role': 'system',
                'content': f'You know about this {analyzedDocumentContent}'
            }
        ]
    )
    return response.choices[0].message.content

# %%
def get_tables_in_document(tables) -> list:
    tableTotalObjects = []    
    # Get objects in tables
    for table in tables:
        if table.cells:
            first_cell = table.cells[0]
            if 'boundingRegions' in first_cell and first_cell['boundingRegions']:
                first_bounding_region = first_cell['boundingRegions'][0]
                if 'pageNumber' in first_bounding_region:
                    result = {
                        "pageNumber": first_bounding_region['pageNumber'],
                        "identifier": str(abs(hash(str(first_bounding_region['polygon']))) % (10 ** 8)),
                        "type": "table",
                        "objectContent": table
                    }
                    tableTotalObjects.append(result.copy())
    
    return tableTotalObjects

# %%
def get_images_in_document(document):
    imagesTotalObjects = []
    for page_num, page in enumerate(document.pages()):
        for img_num, img in enumerate(page.get_images(full=True)):
            result = {
                "pageNumber": page_num+1,
                "identifier": str(abs(hash(str(img))) % (10 ** 8)),
                "type": "figure",
                "objectContent": img
            }
            xref = img[0]
            base_image = document.extract_image(xref)
            image = Image.open(io.BytesIO(base_image["image"]))
            image.save(f"{result['identifier']}.png")
            imagesTotalObjects.append(result.copy())
    return imagesTotalObjects

# %%
def join_content_with_identifiers(analyzedDocumentContent_split_by_page, objectsInDocument):
    for page in analyzedDocumentContent_split_by_page:
        identifiers = [obj['identifier'] for obj in objectsInDocument if obj['pageNumber'] == page['pageNumber']]
        if identifiers:
            page['identifier'] = ', '.join(identifiers)
        else:
            page['identifier'] = None
    return analyzedDocumentContent_split_by_page

# %%
def describe_figure(image_as_bytes):
    encoded_image = base64.b64encode(image_as_bytes.read()).decode('utf-8')
    res = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": f"Describe all images or graphs which you can see inside the provided image as best as you can and include as much as information as you can see. If and image contains a coordinate system, also extract data from all axes and get axis values for each bar or line. "},
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/png;base64,{encoded_image}"}
                    },
                ],
            }
        ],
    )
    return res.choices[0].message.content

# %%
def append_objects_to_pagelist(analyzedDocumentContent_split_by_page,objectsInDocument):
    result = []
    for page in analyzedDocumentContent_split_by_page:
        for obj in objectsInDocument:
            if obj['pageNumber'] == page['pageNumber']:
                page.update(obj)
                result.append(page.copy())
    return result

# %%
#filename = "Osterbaan.Amy_.ScholarshipDayPoster3.pdf"
#filename = "aspirin.pdf"
#filename = "nov_real_1.pdf"
filename = "wildfire.pdf"
with open(filename, "rb") as f:
    documentcontent = f.read()

doc = fitz.open(filename)

# %%
documentcontent
# Out:
# b'%PDF-1.7\n%\xe2\xe3\xcf\xd3\n626 0 obj\n<</ByteRange [0 142 195908 239918 ]                                                          /ContactInfo()/Contents <...>/Filter/Adobe.PPKLite/Location()/M(D:20230605102302-04\'00\')/Prop_Build<</App<</Name/>>>>/Reason()/Reference[<</Data 1 0 R/TransformMethod/DocMDP/TransformParams<</P 1/Type/TransformParams/V/1.2>>/Type/SigRef>>]/SubFilter/adbe.pkcs7.detached/Type/Sig>>\nendobj\n4 0 obj\n<</Filter/FlateDecode/Length 9636>>stream\nx\x9c\xed]\xebs\x1b9r\xff\xee*\xff\x0f\xf3%U\xe4\x954\x1e\xbc\xe6\xb1\xd9l\x95w\xf7|\xf1Un\xf7\x12\xfbj+\xb5{\x1fhj$\xf1\x8e"u\x14e\xc7\xf9\xeb\x83n`^l\x003\x1c\x81\xc9\x97l\xd5\xca\x129\x98_\xa3\xd1\xe8\x17\x1a\xc0\x9b\xb7\x87\xe3\xe6v\xb5>&\xdf~\xfb\xe6\xed\xf1\xb8Z\xdf\xd77\xc9\xafo>\xee\x1f\xff\xfa\xe6\xe3\xd7\xc7\xfa\xcd\x9fWw\x9b\xdd\xea\xb8\xd9\xef\xde|x\xfet\x84\x8f\xfe\xb5^\xdd\xd4\x87\xef\xbeK\xbe\xff\xf1\x87\xe4\x1f\xaf_ei\x06\xffU\x8c\'Y\x92\xeb\x9fE\xc5\x93C\xfd\xfa\xd5/\xbfKv\xaf_}\xff\xf1\xf5\xab7\xefX\xa2\xbf\xf8x\xfb\xfa\x15\xd3\x0fe\tK\x94\x92\xa9J\xf2\xaaJ\xb9\xfe\xe2A?\xf3\x87\x0fEr\xf7\xa4\xdf\x97\xdc\xe1_\xa5\xfd\xeb\x0f\xaf_\xfd\xbaH\x96\x7fM>\xfe\xf1\xf5\xab\xdf\xeb\xb7\xfd\xfb\xebW\xc9\xef\xff\xf4C\xf2\xc6C\xfd\xf7\xfb\xe3q\xff\xe0\xef\xc0\xbb\xfd\xfexv\x07xR\r\xe8\xe7R\xa6\xb2Jx\x81\xc4g)\x17*\xc9RY\xe8\xef\xd3<\x93\xc9\xe1\xce\xf5\xe9\x7f`g\xee\x97\xd7bq<\xc2\xcfG\xf8\xf1\xb4,\x16\xdf\xbc\x81\xdf\xde\xac\x97\xd7\xe5\xe2\xb0d\xf0\xe1u\xbe8\xd4\xe6\xa1j\xb1\x87_\x0e\xc7\xa7\xa5\\\xa4\xf8\xd0^\x7f\xb8\x83\x0f\xef\xf0\x9bZ\xff\x89M\xf0G\xbad\xcc|\x01\x8f}\x1e2on\x97E^\xa4\xb9\x98\xd7\xe5s\xc6\xef,\xe9S\x9a&#F*\x91U\x9e\xe6UR\xf14\x13\xbd\xde\xd8\x8f\xa1\x13\xf0\x95J\xfam\xd6 z\xef\x1fVw5c\xc9\x8f\xfb\xa4!.y\xf3g \xebO?\xbc\xff1\xc9\xce\x16\xf6*\xad\xf2\x01\xef\xa4\xe6\x1d\xd7\xa0e\x95\x96\xb9\xe1\x1f\x88\xb9\x95\xee\xbf<\xc2\xa0\xdd,\xaf\xd5bu\xaco`x\x93yc\xe6\x80V\x99H\x0b\xe9\x83\xfe\xe3R,\x9e\x01x\x07?\xeaD\x8b"\x83\xdf\xae\x96\xd7\\\x13\xa1\x7f\xf0e\xbe\xc8\xe0#\x0e?\x84c \xfb\xbcbg\xf2J$\xac\x1c\x92\x8b\x83SdiEh\xfde\xb3\x05\x91\xbe\xb9\xdd\x1c\xea\xe4\xc3Q\x0b\xc6\xd3Q\xd3\xbb\xd1\xf3Aj\xb9\x0f\x13\xc6_>\x88\x864Y\xa4LR\xda\xf4\xc4\xdclo\x80\xbe[\xf8\xb19\x00\xef\xea\xa7d\x05\xff\x1e\xe0#\xcd\\Mg\xc7\xecG\xf8\xb1]\xed`\xec\r\xf7\x97,3R\x80\x8c\x1f\xbc\xe7*Y\x96\x8b\xcd\x0e\xde\xb0\xde>\xb7\xe2b>\xb9k\xdbl7w\xfa\xb9{\xf8\xfb\x88_5\x0f\xc4\x92&\xae\xf24c>.\\G\xc4\xa9RQ\xf8p\xd6+\xe0\r\xb2\xf2I\x0b0L\x99"\xe6\x94\xc1\x81\x16yc\x9b\xfa\xd0\xa7\xa3r\xdd\x9f?\xabg \xe4x\xaf\xa5r\x0f\x7f\xe3\xb8o\xfe\xbb\x99\xd2\x95\x19\x19|\xfe\x01\xc6e\x05#\xbe\x8bF7\xcby*J\x1f\xe5\xf1\x06\x87\xe5\nU\x8a\x1b\xa7\x19\x9c|06\x0e\x81\xd6\x7f\x81\xf4\x17=\x99\xaf\x9f\xd6\xabG\xf8H7\x93\x11G\x94\xe7Z\x9c\xc4\xa41\x8d-F\\\xa5\xa0\xe2\\\x90\x07c\xa1\x1bi\x88\x87\\Ti\xa1m\xaf\x07\xfbQ\x0f\x8d\xd1HOk#\xa1\x9f\x00>\xf6,b\xdc\x18\x1e7\x11\x9f\xda\x99\x80$\xec4M\x11\xa1\xb5w\x96s\x7f\xff\x11\xb54\xac\xff[\xbd>>\xa5(\x8d`Sj\x10Z\x94\xc5\xd5\xc1\x9aD\xcd\x1b\xcb\xae\xc7v\xc0v\x8d\xee1\xbc\xdb\xd6I\xab\xfa\xbb\x99\x1f[\x94\x98t)C7m\x8dy(z\xd6\xe1\xb87b\xa6\x7f\xfd\x82\xc6J\x9e\x88\xfe\xf1\xde\xf8 `l>\xb5&\xe9\xae\xb34\xd8v\x1foZf\xdaad\xbe\x8e\xed\x0c\xe1\x95\xf9\xc5v-7$\x1ba\xadq\x88V[\xa0\xf7\xb7\x85\xf1\xa5\xb5k\xadG\xf1*\xee\x842\xfc\xd7\x9e\x94C{l\x91\xabF\xebm\xafP\\\x06j\xadj\x04\x0e8\xfd\x19\xbf>\xd6\xbf-\xc1\x86\x1b\x9b\xad\x9f\xb6\xe3\x05\xd4w\x9eW\xfd_\xf0\x96u\xad;\x87o8&\xb7-#\xac|asp\xf6\xbb1o\xe5\xb7C\xc5\x16G-\xe7\xf0\xaaN\xd9\xe2\x08\x7f\x8d:\xf1\x90OJ\xbb\xd9>\x95w:n`\x03\xee\xf0#c\n\xf5\xc7\xeb\x8d\x96D4\xa4]\xa7t\x03\xcb\xad\xf5\x1e\xbe\xd9\xeb?\x1f\xdb/\xb4\'\xf8\xb9\x9b\xab\xe6}fV`\xfc\x84\xca\xb5\xc6!1\x01T\xcb\xe1\x8f\xf0\xe3^\xbf\xc1\xb4\xecS\x08\xe4\xe0;\x80\xca\xb8\xec)\x99K\xda\xef\xda\xb1\xfd\xdcvl\xd7\xda\x06K~\xb2yJ\x0e\xf8wX\x17\x95T\x15U\x97Q\x14qY\xa3\xfd~\xc7\x0c3\xaa\x08\x87u\xa0\x86\xf2FE4\xce\x85k\xec`V\x1a\'\xbb\x9d\x1e}\x01\xb0>\x99\x11\x80w\xfbe\xd9\xb0\xe9\x98|\xa8\x91\xd58\x1c\x9b5<\xa1\xac\x96y\xf7A\x8b\x91\x9e\xc2\xb3:/\ ...

# %%
analyzedDocumentContent = analyze_document(documentcontent)
print(analyzedDocumentContent)
# Out:
# {'apiVersion': '2024-02-29-preview', 'modelId': 'prebuilt-layout', 'stringIndexType': 'textElements', 'content': '<figure>\n\n![](figures/0)\n\n<!-- FigureContent="Congressional Research Service Informing the legislative debate since 1914" -->\n\n</figure>\n\n\nIN FOCUS\n\nUpdated June 1, 2023\n\n\n# Wildfire Statistics\n\nWildfires are unplanned fires, including lightning-caused fires, unauthorized human-caused fires, and escaped fires from prescribed burn projects. States are responsible for responding to wildfires that begin on nonfederal (state, local, and private) lands, except for lands protected by federal agencies under cooperative agreements. The federal government is responsible for responding to wildfires that begin on federal lands. The Forest Service (FS)-within the U.S. Department of Agriculture-carries out wildfire management and response across the 193 million acres of the National Forest System (NFS). The Department of the Interior (DOI) manages wildfire response for more than 400 million acres of national parks, wildlife refuges and preserves, other public lands, and Indian reservations.\n\nWildfire statistics help illustrate past U.S. wildfire activity. Nationwide data compiled by the National Interagency Coordination Center (NICC) indicate that the number of annual wildfires is variable but has decreased slightly over the last 30 years. The number of acres affected annually, while also variable, generally has increased (see Figure 1). Since 2000, an annual average of 70,025 wildfires have burned an annual average of 7.0 million acres. The acreage figure is more than double the average annual acreage burned in the 1990s (3.3 million acres), although a greater number of fires occurred annually in the 1990s on average (78,600).\n\nTable 1. Annual Wildfires and Acres Burned\n\n| | 2018 | 2019 | 2020 | 2021 | 2022 |\n| - | - | - | - | - | - |\n| Number of Fires (thousands) ||||||\n| Federal | 12.5 | 10.9 | 14.4 | 14.0 | 11.7 |\n| FS | 5.6 | 5.3 | 6.7 | 6.2 | 5.9 |\n| DOI | 7.0 | 5.3 | 7.6 | 7.6 | 5.8 |\n| Other | 0.1 | 0.2 | <0.1 | 0.2 | 0.1 |\n| Nonfederal | 45.6 | 39.6 | 44.6 | 45.0 | 57.2 |\n| Total | 58.1 | 50.5 | 59.0 | 59.0 | 69.0 |\n| Acres Burned (millions) ||||||\n| Federal | 4.6 | 3.1 | 7.1 | 5.2 | 4.0 |\n| FS | 2.3 | 0.6 | 4.8 | 4.1 | 1.9 |\n| DOI | 2.3 | 2.3 | 2.3 | 1.0 | 2.1 |\n| Other | <0.1 | <0.1 | <0.1 | < 0. | <0.1 |\n| Nonfederal | 4.1 | 1.6 | 3.1 | 1.9 | 3.6 |\n| Total | 8.8 | 4.7 | 10.1 | 7.1 | 7.6 |\n\nSource: National Interagency Coordination Center (NICC) Wildland Fire Summary and Statistics annual reports. Notes: FS = Forest Service; DOI = Department of the Interior. Column totals may not sum precisely due to rounding.\n\nFigure 1. Annual Wildfires and Acres Burned, 1993-2022\n\n<figure>\n\n![](figures/1)\n\n<!-- FigureContent="Fires, thousands Acres burned, millions 120 12 100 Fires 10 80 8 60 6 40 4 20 Acres burned 2 0 1993- 1998- 2003. 2008- 2013 2018- 2022- 0" -->\n\n</figure>\n\n\nSource: NICC Wildland Fire Summary and Statistics annual reports. Note: Data reflect wildland fires and acres burned nationwide, including wildland fires on federal and nonfederal lands.\n\nFrom 2013 to 2022, there were an average of 61,410 wildfires annually and an average of 7.2 million acres impacted annually. In 2022, 68,988 wildfires burned 7.6 million acres. Over 40% of those acres were in Alaska (3.1 million acres).\n\nAs of June 1, 2023, around 18,300 wildfires have impacted over 511,000 acres this year.\n\nFigure 2. Top Five Years with Largest Wildfire Acreage Burned Since 1960\n\n<figure>\n\n![](figures/2)\n\n<!-- FigureContent="Year Acres burned (millions) Number of Fires 2015 10.13 68.2 2020 10.12 59.0 2017 10.03 71.5 2006 9.87 96.4 2007 9.33 67.8" -->\n\n</figure>\n\n\nSource: NICC Wildland Fire Summary and Statistics annual reports. Note: Number of fires in thousands.\n\nThe number of fires and acreage burned are indicators of the annual level of wildfire activity. These numbers may not be in ...

# %%
analyzedDocumentContent_split_by_page = split_document_to_pages(analyzedDocumentContent)

# %%
analyzedDocumentContent_split_by_page
# Out:
# [{'pageNumber': 1,
#   'pageContent': '<!-- FigureContent="Congressional Research Service Informing the legislative debate since 1914" --> IN FOCUS Updated June 1, 2023 # Wildfire Statistics Wildfires are unplanned fires, including lightning-caused fires, unauthorized human-caused fires, and escaped fires from prescribed burn projects. States are responsible for responding to wildfires that begin on nonfederal (state, local, and private) lands, except for lands protected by federal agencies under cooperative agreements. The federal government is responsible for responding to wildfires that begin on federal lands. The Forest Service (FS)-within the U.S. Department of Agriculture-carries out wildfire management and response across the 193 million acres of the National Forest System (NFS). The Department of the Interior (DOI) manages wildfire response for more than 400 million acres of national parks, wildlife refuges and preserves, other public lands, and Indian reservations. Wildfire statistics help illustrate past U.S. wildfire activity. Nationwide data compiled by the National Interagency Coordination Center (NICC) indicate that the number of annual wildfires is variable but has decreased slightly over the last 30 years. The number of acres affected annually, while also variable, generally has increased (see Figure 1). Since 2000, an annual average of 70,025 wildfires have burned an annual average of 7.0 million acres. The acreage figure is more than double the average annual acreage burned in the 1990s (3.3 million acres), although a greater number of fires occurred annually in the 1990s on average (78,600). Table 1. Annual Wildfires and Acres Burned 2018 2019 2020 2021 2022 Number of Fires (thousands) Federal 12.5 10.9 14.4 14.0 11.7 FS 5.6 5.3 6.7 6.2 5.9 DOI 7.0 5.3 7.6 7.6 5.8 Other 0.1 0.2 <0.1 0.2 0.1 Nonfederal 45.6 39.6 44.6 45.0 57.2 Total 58.1 50.5 59.0 59.0 69.0 Acres Burned (millions) Federal 4.6 3.1 7.1 5.2 4.0 FS 2.3 0.6 4.8 4.1 1.9 DOI 2.3 2.3 2.3 1.0 2.1 Other <0.1 <0.1 <0.1 < 0. <0.1 Nonfederal 4.1 1.6 3.1 1.9 3.6 Total 8.8 4.7 10.1 7.1 7.6 Source: National Interagency Coordination Center (NICC) Wildland Fire Summary and Statistics annual reports. Notes: FS = Forest Service; DOI = Department of the Interior. Column totals may not sum precisely due to rounding. Figure 1. Annual Wildfires and Acres Burned, 1993-2022 <!-- FigureContent="Fires, thousands Acres burned, millions 120 12 100 Fires 10 80 8 60 6 40 4 20 Acres burned 2 0 1993- 1998- 2003. 2008- 2013 2018- 2022- 0" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Data reflect wildland fires and acres burned nationwide, including wildland fires on federal and nonfederal lands. From 2013 to 2022, there were an average of 61,410 wildfires annually and an average of 7.2 million acres impacted annually. In 2022, 68,988 wildfires burned 7.6 million acres. Over 40% of those acres were in Alaska (3.1 million acres). As of June 1, 2023, around 18,300 wildfires have impacted over 511,000 acres this year. Figure 2. Top Five Years with Largest Wildfire Acreage Burned Since 1960 <!-- FigureContent="Year Acres burned (millions) Number of Fires 2015 10.13 68.2 2020 10.12 59.0 2017 10.03 71.5 2006 9.87 96.4 2007 9.33 67.8" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Number of fires in thousands. The number of fires and acreage burned are indicators of the annual level of wildfire activity. These numbers may not be indicative of fire\'s impact on human development or communities, since many fires occur in large, relatively undeveloped areas. Acreage burned also does not indicate the severity of a wildfire, the degree of impact upon forests or soils, or other ecological effects. Most wildfires are human-caused (89% of the average number of wildfires from 2018 to 2022). Wildfires caused by lightning tend to be slightly larger and to burn more acreage (53% of the average acreage burned from 2018 to 2022) than human-caused fires. <!-- P ...
#   'identifier': None},
#  {'pageNumber': 2,
#   'pageContent': '<!-- PageHeader="Wildfire Statistics" --> In 2022, 52% of the nationwide acreage burned by wildfires was on federal lands (4.0 million acres; see Table 1), lower than the 10-year average (64%) of impacted federal land acreage. The other 48% of the acreage burned in 2022 was on state, local, or privately owned lands, though the fires on these lands accounted for 83% of total fires. Of the federal acreage burned nationwide in 2022, 52% (2.1 million acres) burned on DOI land and 47% (1.9 million acres) burned on FS land (see Figure 3). The 2022 figures are driven largely by Alaska, where just over half of the acreage impacted occurred on nonfederal lands (1.6 million acres) and just under half was on DOI lands (1.5 million acres). Figure 3. Percentage Acreage Burned by Ownership <!-- FigureContent="100% Non- federal 75% Other federal 50% DOI 25% Forest 0% Service 2018 2019 2020 2021 2022" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: DOI = Department of the Interior. More wildfires occur in the East (including the central states), but the wildfires in the West (i.e., Alaska, Arizona, California, Colorado, Idaho, Montana, New Mexico, Nevada, Oregon, Utah, Washington, and Wyoming) are larger and burn more acreage. In 2022, just over 20,000 wildfires burned approximately 5.8 million acres in the West, compared with the over 48,000 fires that burned just over 1.8 million acres in the East. In the East (where there is less federal acreage), most of the fires occur on nonfederal lands; in the West, most of the fires occur on federal lands (see Figure 4). In 2022, 85% (1.5 million acres) of the acreage burned in the East was on nonfederal land, whereas 64% (3.7 million acres) of the acreage burned in the West was on federal land. Figure 4. Acreage Burned by Region and Ownership <!-- FigureContent="Acres burned, millions 12 East Nonfederal 10 8 East Federal 6 4 West Nonfederal 2 West Federal 0 2018 2019 2020 2021 2022" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Notes: West: AK, AZ, CA, CO, ID, HI, MT, NM, NV, OR, UT, WA, and WY. East: All other states and Puerto Rico. ## Resources Another metric useful for assessing wildfire activity is the extent to which nationwide resources-including personnel and equipment are engaged in wildfire suppression. A proxy for resource commitments is the nationwide Preparedness Level (PL) scale, which ranges from 1 (lowest) to 5 (highest). The higher PLs indicate significant commitment of shared resources. In 2022, the nationwide level was 4 for 10 days and never reached the highest level (5). In contrast, the highest level was reached for 68 days in 2021, the longest since at least 2000. ## Wildfire Damages Wildfires may affect certain ecological resources beneficially, but wildfires also may have devastating impacts, especially for communities affected by wildfire activity. Statistics showing the level of destruction a wildfire caused can provide useful metrics to evaluate the fire\'s effect. Such statistics may include acres burned or impacted, lives lost (firefighters and civilians), and structures (residential, commercial, and other) destroyed. For example, in 2022, over 2,700 structures were burned in wildfires; the majority of the damage occurred in California (see Table 2). Table 2. Loss Statistics 2019 2020 2021 2022 Structures Burned 963 17,904 5,972 2,717 % Residences 46% 54% 60% 46% Source: NICC Wildland Fire Summary and Statistics annual reports. ## Conflagrations Of the 1.6 million wildfires that have occurred since 2000, 254 exceeded 100,000 acres burned and 16 exceeded 500,000 acres burned. A small fraction of wildfires become catastrophic, and a small percentage of fires accounts for the vast majority of acres burned. For example, about 1% of wildfires become conflagrations-raging, destructive fires-but predicting which fires will "blow up" into conflagrations is challenging and depends on a multitude of factors, su ...
#   'identifier': None},
#  {'pageNumber': 3,
#   'pageContent': '<!-- PageHeader="Wildfire Statistics" --> # Disclaimer This document was prepared by the Congressional Research Service (CRS). CRS serves as nonpartisan shared staff to congressional committees and Members of Congress. It operates solely at the behest of and under the direction of Congress. Information in a CRS Report should not be relied upon for purposes other than public understanding of information that has been provided by CRS to Members of Congress in connection with CRS\'s institutional role. CRS Reports, as a work of the United States Government, are not subject to copyright protection in the United States. Any CRS Report may be reproduced and distributed in its entirety without permission from CRS. However, as a CRS Report may include copyrighted images or material from a third party, you may need to obtain the permission of the copyright holder if you wish to copy or otherwise use copyrighted material. <!-- PageFooter="https://crsreports.congress.gov | IF10244 · VERSION 68 · UPDATED" -->',
#   'identifier': None}]

# %%
tablesInDocument = get_tables_in_document(analyzedDocumentContent['tables'])
imagesInDocument = get_images_in_document(doc)

describedImagesInDocument = []
for image in imagesInDocument:
    with open(f"{image['identifier']}.png", "rb") as f:
        image['objectContent'] = describe_figure(f)
        describedImagesInDocument.append(image)

totalObjectsInDocument = tablesInDocument + describedImagesInDocument

# %%
content_index = join_content_with_identifiers(analyzedDocumentContent_split_by_page, totalObjectsInDocument)
content_index
# Out:
# [{'pageNumber': 1,
#   'pageContent': '<!-- FigureContent="Congressional Research Service Informing the legislative debate since 1914" --> IN FOCUS Updated June 1, 2023 # Wildfire Statistics Wildfires are unplanned fires, including lightning-caused fires, unauthorized human-caused fires, and escaped fires from prescribed burn projects. States are responsible for responding to wildfires that begin on nonfederal (state, local, and private) lands, except for lands protected by federal agencies under cooperative agreements. The federal government is responsible for responding to wildfires that begin on federal lands. The Forest Service (FS)-within the U.S. Department of Agriculture-carries out wildfire management and response across the 193 million acres of the National Forest System (NFS). The Department of the Interior (DOI) manages wildfire response for more than 400 million acres of national parks, wildlife refuges and preserves, other public lands, and Indian reservations. Wildfire statistics help illustrate past U.S. wildfire activity. Nationwide data compiled by the National Interagency Coordination Center (NICC) indicate that the number of annual wildfires is variable but has decreased slightly over the last 30 years. The number of acres affected annually, while also variable, generally has increased (see Figure 1). Since 2000, an annual average of 70,025 wildfires have burned an annual average of 7.0 million acres. The acreage figure is more than double the average annual acreage burned in the 1990s (3.3 million acres), although a greater number of fires occurred annually in the 1990s on average (78,600). Table 1. Annual Wildfires and Acres Burned 2018 2019 2020 2021 2022 Number of Fires (thousands) Federal 12.5 10.9 14.4 14.0 11.7 FS 5.6 5.3 6.7 6.2 5.9 DOI 7.0 5.3 7.6 7.6 5.8 Other 0.1 0.2 <0.1 0.2 0.1 Nonfederal 45.6 39.6 44.6 45.0 57.2 Total 58.1 50.5 59.0 59.0 69.0 Acres Burned (millions) Federal 4.6 3.1 7.1 5.2 4.0 FS 2.3 0.6 4.8 4.1 1.9 DOI 2.3 2.3 2.3 1.0 2.1 Other <0.1 <0.1 <0.1 < 0. <0.1 Nonfederal 4.1 1.6 3.1 1.9 3.6 Total 8.8 4.7 10.1 7.1 7.6 Source: National Interagency Coordination Center (NICC) Wildland Fire Summary and Statistics annual reports. Notes: FS = Forest Service; DOI = Department of the Interior. Column totals may not sum precisely due to rounding. Figure 1. Annual Wildfires and Acres Burned, 1993-2022 <!-- FigureContent="Fires, thousands Acres burned, millions 120 12 100 Fires 10 80 8 60 6 40 4 20 Acres burned 2 0 1993- 1998- 2003. 2008- 2013 2018- 2022- 0" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Data reflect wildland fires and acres burned nationwide, including wildland fires on federal and nonfederal lands. From 2013 to 2022, there were an average of 61,410 wildfires annually and an average of 7.2 million acres impacted annually. In 2022, 68,988 wildfires burned 7.6 million acres. Over 40% of those acres were in Alaska (3.1 million acres). As of June 1, 2023, around 18,300 wildfires have impacted over 511,000 acres this year. Figure 2. Top Five Years with Largest Wildfire Acreage Burned Since 1960 <!-- FigureContent="Year Acres burned (millions) Number of Fires 2015 10.13 68.2 2020 10.12 59.0 2017 10.03 71.5 2006 9.87 96.4 2007 9.33 67.8" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Number of fires in thousands. The number of fires and acreage burned are indicators of the annual level of wildfire activity. These numbers may not be indicative of fire\'s impact on human development or communities, since many fires occur in large, relatively undeveloped areas. Acreage burned also does not indicate the severity of a wildfire, the degree of impact upon forests or soils, or other ecological effects. Most wildfires are human-caused (89% of the average number of wildfires from 2018 to 2022). Wildfires caused by lightning tend to be slightly larger and to burn more acreage (53% of the average acreage burned from 2018 to 2022) than human-caused fires. <!-- P ...
#   'identifier': '36268147, 65837635, 53267882, 19835683'},
#  {'pageNumber': 2,
#   'pageContent': '<!-- PageHeader="Wildfire Statistics" --> In 2022, 52% of the nationwide acreage burned by wildfires was on federal lands (4.0 million acres; see Table 1), lower than the 10-year average (64%) of impacted federal land acreage. The other 48% of the acreage burned in 2022 was on state, local, or privately owned lands, though the fires on these lands accounted for 83% of total fires. Of the federal acreage burned nationwide in 2022, 52% (2.1 million acres) burned on DOI land and 47% (1.9 million acres) burned on FS land (see Figure 3). The 2022 figures are driven largely by Alaska, where just over half of the acreage impacted occurred on nonfederal lands (1.6 million acres) and just under half was on DOI lands (1.5 million acres). Figure 3. Percentage Acreage Burned by Ownership <!-- FigureContent="100% Non- federal 75% Other federal 50% DOI 25% Forest 0% Service 2018 2019 2020 2021 2022" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: DOI = Department of the Interior. More wildfires occur in the East (including the central states), but the wildfires in the West (i.e., Alaska, Arizona, California, Colorado, Idaho, Montana, New Mexico, Nevada, Oregon, Utah, Washington, and Wyoming) are larger and burn more acreage. In 2022, just over 20,000 wildfires burned approximately 5.8 million acres in the West, compared with the over 48,000 fires that burned just over 1.8 million acres in the East. In the East (where there is less federal acreage), most of the fires occur on nonfederal lands; in the West, most of the fires occur on federal lands (see Figure 4). In 2022, 85% (1.5 million acres) of the acreage burned in the East was on nonfederal land, whereas 64% (3.7 million acres) of the acreage burned in the West was on federal land. Figure 4. Acreage Burned by Region and Ownership <!-- FigureContent="Acres burned, millions 12 East Nonfederal 10 8 East Federal 6 4 West Nonfederal 2 West Federal 0 2018 2019 2020 2021 2022" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Notes: West: AK, AZ, CA, CO, ID, HI, MT, NM, NV, OR, UT, WA, and WY. East: All other states and Puerto Rico. ## Resources Another metric useful for assessing wildfire activity is the extent to which nationwide resources-including personnel and equipment are engaged in wildfire suppression. A proxy for resource commitments is the nationwide Preparedness Level (PL) scale, which ranges from 1 (lowest) to 5 (highest). The higher PLs indicate significant commitment of shared resources. In 2022, the nationwide level was 4 for 10 days and never reached the highest level (5). In contrast, the highest level was reached for 68 days in 2021, the longest since at least 2000. ## Wildfire Damages Wildfires may affect certain ecological resources beneficially, but wildfires also may have devastating impacts, especially for communities affected by wildfire activity. Statistics showing the level of destruction a wildfire caused can provide useful metrics to evaluate the fire\'s effect. Such statistics may include acres burned or impacted, lives lost (firefighters and civilians), and structures (residential, commercial, and other) destroyed. For example, in 2022, over 2,700 structures were burned in wildfires; the majority of the damage occurred in California (see Table 2). Table 2. Loss Statistics 2019 2020 2021 2022 Structures Burned 963 17,904 5,972 2,717 % Residences 46% 54% 60% 46% Source: NICC Wildland Fire Summary and Statistics annual reports. ## Conflagrations Of the 1.6 million wildfires that have occurred since 2000, 254 exceeded 100,000 acres burned and 16 exceeded 500,000 acres burned. A small fraction of wildfires become catastrophic, and a small percentage of fires accounts for the vast majority of acres burned. For example, about 1% of wildfires become conflagrations-raging, destructive fires-but predicting which fires will "blow up" into conflagrations is challenging and depends on a multitude of factors, su ...
#   'identifier': '61670436, 634444, 31358356'},
#  {'pageNumber': 3,
#   'pageContent': '<!-- PageHeader="Wildfire Statistics" --> # Disclaimer This document was prepared by the Congressional Research Service (CRS). CRS serves as nonpartisan shared staff to congressional committees and Members of Congress. It operates solely at the behest of and under the direction of Congress. Information in a CRS Report should not be relied upon for purposes other than public understanding of information that has been provided by CRS to Members of Congress in connection with CRS\'s institutional role. CRS Reports, as a work of the United States Government, are not subject to copyright protection in the United States. Any CRS Report may be reproduced and distributed in its entirety without permission from CRS. However, as a CRS Report may include copyrighted images or material from a third party, you may need to obtain the permission of the copyright holder if you wish to copy or otherwise use copyrighted material. <!-- PageFooter="https://crsreports.congress.gov | IF10244 · VERSION 68 · UPDATED" -->',
#   'identifier': None}]

# %% [markdown]
# Simulate an RAG Pattern

# %% [markdown]
# ### assuming this is in the content index

# %%
content_index
# Out:
# [{'pageNumber': 1,
#   'pageContent': '<!-- FigureContent="Congressional Research Service Informing the legislative debate since 1914" --> IN FOCUS Updated June 1, 2023 # Wildfire Statistics Wildfires are unplanned fires, including lightning-caused fires, unauthorized human-caused fires, and escaped fires from prescribed burn projects. States are responsible for responding to wildfires that begin on nonfederal (state, local, and private) lands, except for lands protected by federal agencies under cooperative agreements. The federal government is responsible for responding to wildfires that begin on federal lands. The Forest Service (FS)-within the U.S. Department of Agriculture-carries out wildfire management and response across the 193 million acres of the National Forest System (NFS). The Department of the Interior (DOI) manages wildfire response for more than 400 million acres of national parks, wildlife refuges and preserves, other public lands, and Indian reservations. Wildfire statistics help illustrate past U.S. wildfire activity. Nationwide data compiled by the National Interagency Coordination Center (NICC) indicate that the number of annual wildfires is variable but has decreased slightly over the last 30 years. The number of acres affected annually, while also variable, generally has increased (see Figure 1). Since 2000, an annual average of 70,025 wildfires have burned an annual average of 7.0 million acres. The acreage figure is more than double the average annual acreage burned in the 1990s (3.3 million acres), although a greater number of fires occurred annually in the 1990s on average (78,600). Table 1. Annual Wildfires and Acres Burned 2018 2019 2020 2021 2022 Number of Fires (thousands) Federal 12.5 10.9 14.4 14.0 11.7 FS 5.6 5.3 6.7 6.2 5.9 DOI 7.0 5.3 7.6 7.6 5.8 Other 0.1 0.2 <0.1 0.2 0.1 Nonfederal 45.6 39.6 44.6 45.0 57.2 Total 58.1 50.5 59.0 59.0 69.0 Acres Burned (millions) Federal 4.6 3.1 7.1 5.2 4.0 FS 2.3 0.6 4.8 4.1 1.9 DOI 2.3 2.3 2.3 1.0 2.1 Other <0.1 <0.1 <0.1 < 0. <0.1 Nonfederal 4.1 1.6 3.1 1.9 3.6 Total 8.8 4.7 10.1 7.1 7.6 Source: National Interagency Coordination Center (NICC) Wildland Fire Summary and Statistics annual reports. Notes: FS = Forest Service; DOI = Department of the Interior. Column totals may not sum precisely due to rounding. Figure 1. Annual Wildfires and Acres Burned, 1993-2022 <!-- FigureContent="Fires, thousands Acres burned, millions 120 12 100 Fires 10 80 8 60 6 40 4 20 Acres burned 2 0 1993- 1998- 2003. 2008- 2013 2018- 2022- 0" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Data reflect wildland fires and acres burned nationwide, including wildland fires on federal and nonfederal lands. From 2013 to 2022, there were an average of 61,410 wildfires annually and an average of 7.2 million acres impacted annually. In 2022, 68,988 wildfires burned 7.6 million acres. Over 40% of those acres were in Alaska (3.1 million acres). As of June 1, 2023, around 18,300 wildfires have impacted over 511,000 acres this year. Figure 2. Top Five Years with Largest Wildfire Acreage Burned Since 1960 <!-- FigureContent="Year Acres burned (millions) Number of Fires 2015 10.13 68.2 2020 10.12 59.0 2017 10.03 71.5 2006 9.87 96.4 2007 9.33 67.8" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Number of fires in thousands. The number of fires and acreage burned are indicators of the annual level of wildfire activity. These numbers may not be indicative of fire\'s impact on human development or communities, since many fires occur in large, relatively undeveloped areas. Acreage burned also does not indicate the severity of a wildfire, the degree of impact upon forests or soils, or other ecological effects. Most wildfires are human-caused (89% of the average number of wildfires from 2018 to 2022). Wildfires caused by lightning tend to be slightly larger and to burn more acreage (53% of the average acreage burned from 2018 to 2022) than human-caused fires. <!-- P ...
#   'identifier': '36268147, 65837635, 53267882, 19835683'},
#  {'pageNumber': 2,
#   'pageContent': '<!-- PageHeader="Wildfire Statistics" --> In 2022, 52% of the nationwide acreage burned by wildfires was on federal lands (4.0 million acres; see Table 1), lower than the 10-year average (64%) of impacted federal land acreage. The other 48% of the acreage burned in 2022 was on state, local, or privately owned lands, though the fires on these lands accounted for 83% of total fires. Of the federal acreage burned nationwide in 2022, 52% (2.1 million acres) burned on DOI land and 47% (1.9 million acres) burned on FS land (see Figure 3). The 2022 figures are driven largely by Alaska, where just over half of the acreage impacted occurred on nonfederal lands (1.6 million acres) and just under half was on DOI lands (1.5 million acres). Figure 3. Percentage Acreage Burned by Ownership <!-- FigureContent="100% Non- federal 75% Other federal 50% DOI 25% Forest 0% Service 2018 2019 2020 2021 2022" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: DOI = Department of the Interior. More wildfires occur in the East (including the central states), but the wildfires in the West (i.e., Alaska, Arizona, California, Colorado, Idaho, Montana, New Mexico, Nevada, Oregon, Utah, Washington, and Wyoming) are larger and burn more acreage. In 2022, just over 20,000 wildfires burned approximately 5.8 million acres in the West, compared with the over 48,000 fires that burned just over 1.8 million acres in the East. In the East (where there is less federal acreage), most of the fires occur on nonfederal lands; in the West, most of the fires occur on federal lands (see Figure 4). In 2022, 85% (1.5 million acres) of the acreage burned in the East was on nonfederal land, whereas 64% (3.7 million acres) of the acreage burned in the West was on federal land. Figure 4. Acreage Burned by Region and Ownership <!-- FigureContent="Acres burned, millions 12 East Nonfederal 10 8 East Federal 6 4 West Nonfederal 2 West Federal 0 2018 2019 2020 2021 2022" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Notes: West: AK, AZ, CA, CO, ID, HI, MT, NM, NV, OR, UT, WA, and WY. East: All other states and Puerto Rico. ## Resources Another metric useful for assessing wildfire activity is the extent to which nationwide resources-including personnel and equipment are engaged in wildfire suppression. A proxy for resource commitments is the nationwide Preparedness Level (PL) scale, which ranges from 1 (lowest) to 5 (highest). The higher PLs indicate significant commitment of shared resources. In 2022, the nationwide level was 4 for 10 days and never reached the highest level (5). In contrast, the highest level was reached for 68 days in 2021, the longest since at least 2000. ## Wildfire Damages Wildfires may affect certain ecological resources beneficially, but wildfires also may have devastating impacts, especially for communities affected by wildfire activity. Statistics showing the level of destruction a wildfire caused can provide useful metrics to evaluate the fire\'s effect. Such statistics may include acres burned or impacted, lives lost (firefighters and civilians), and structures (residential, commercial, and other) destroyed. For example, in 2022, over 2,700 structures were burned in wildfires; the majority of the damage occurred in California (see Table 2). Table 2. Loss Statistics 2019 2020 2021 2022 Structures Burned 963 17,904 5,972 2,717 % Residences 46% 54% 60% 46% Source: NICC Wildland Fire Summary and Statistics annual reports. ## Conflagrations Of the 1.6 million wildfires that have occurred since 2000, 254 exceeded 100,000 acres burned and 16 exceeded 500,000 acres burned. A small fraction of wildfires become catastrophic, and a small percentage of fires accounts for the vast majority of acres burned. For example, about 1% of wildfires become conflagrations-raging, destructive fires-but predicting which fires will "blow up" into conflagrations is challenging and depends on a multitude of factors, su ...
#   'identifier': '61670436, 634444, 31358356'},
#  {'pageNumber': 3,
#   'pageContent': '<!-- PageHeader="Wildfire Statistics" --> # Disclaimer This document was prepared by the Congressional Research Service (CRS). CRS serves as nonpartisan shared staff to congressional committees and Members of Congress. It operates solely at the behest of and under the direction of Congress. Information in a CRS Report should not be relied upon for purposes other than public understanding of information that has been provided by CRS to Members of Congress in connection with CRS\'s institutional role. CRS Reports, as a work of the United States Government, are not subject to copyright protection in the United States. Any CRS Report may be reproduced and distributed in its entirety without permission from CRS. However, as a CRS Report may include copyrighted images or material from a third party, you may need to obtain the permission of the copyright holder if you wish to copy or otherwise use copyrighted material. <!-- PageFooter="https://crsreports.congress.gov | IF10244 · VERSION 68 · UPDATED" -->',
#   'identifier': None}]

# %% [markdown]
# ### assuming this is in the object index

# %%
totalObjectsInDocument
# Out:
# [{'pageNumber': 1,
#   'identifier': '36268147',
#   'type': 'table',
#   'objectContent': {'rowCount': 15, 'columnCount': 6, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.3451, 1.6522, 6.3451, 1.6522, 6.6506, 0.7784, 6.6506]}], 'spans': []}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': '2018', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6522, 6.3451, 2.211, 6.3451, 2.211, 6.6506, 1.6522, 6.6506]}], 'spans': [{'offset': 1692, 'length': 4}], 'elements': ['/paragraphs/7']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': '2019', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 6.3451, 2.7124, 6.3451, 2.7124, 6.6506, 2.211, 6.6506]}], 'spans': [{'offset': 1699, 'length': 4}], 'elements': ['/paragraphs/8']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': '2020', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7124, 6.3451, 3.209, 6.3451, 3.209, 6.6506, 2.7124, 6.6506]}], 'spans': [{'offset': 1706, 'length': 4}], 'elements': ['/paragraphs/9']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': '2021', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.209, 6.3451, 3.6817, 6.3451, 3.6817, 6.6506, 3.209, 6.6506]}], 'spans': [{'offset': 1713, 'length': 4}], 'elements': ['/paragraphs/10']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 5, 'content': '2022', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.6817, 6.3451, 4.1354, 6.3451, 4.1354, 6.6554, 3.6817, 6.6506]}], 'spans': [{'offset': 1720, 'length': 4}], 'elements': ['/paragraphs/11']}, {'rowIndex': 1, 'columnIndex': 0, 'columnSpan': 6, 'content': 'Number of Fires (thousands)', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.6506, 4.1354, 6.6554, 4.1354, 6.8845, 0.7784, 6.8845]}], 'spans': [{'offset': 1755, 'length': 27}], 'elements': ['/paragraphs/12']}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Federal', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.8845, 1.6522, 6.8845, 1.6475, 7.1042, 0.7784, 7.1089]}], 'spans': [{'offset': 1792, 'length': 7}], 'elements': ['/paragraphs/13']}, {'rowIndex': 2, 'columnIndex': 1, 'content': '12.5', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6522, 6.8845, 2.211, 6.8845, 2.211, 7.1042, 1.6475, 7.1042]}], 'spans': [{'offset': 1802, 'length': 4}], 'elements': ['/paragraphs/14']}, {'rowIndex': 2, 'columnIndex': 2, 'content': '10.9', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 6.8845, 2.7124, 6.8845, 2.7124, 7.1042, 2.211, 7.1042]}], 'spans': [{'offset': 1809, 'length': 4}], 'elements': ['/paragraphs/15']}, {'rowIndex': 2, 'columnIndex': 3, 'content': '14.4', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7124, 6.8845, 3.209, 6.8845, 3.209, 7.1042, 2.7124, 7.1042]}], 'spans': [{'offset': 1816, 'length': 4}], 'elements': ['/paragraphs/16']}, {'rowIndex': 2, 'columnIndex': 4, 'content': '14.0', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.209, 6.8845, 3.6817, 6.8845, 3.6817, 7.1042, 3.209, 7.1042]}], 'spans': [{'offset': 1823, 'length': 4}], 'elements': ['/paragraphs/17']}, {'rowIndex': 2, 'columnIndex': 5, 'content': '11.7', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.6817, 6.8845, 4.1354, 6.8845, 4.1354, 7.1042, 3.6817, 7.1042]}], 'spans': [{'offset': 1830, 'length': 4}], 'elements': ['/paragraphs/18']}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'FS', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 7.1089, 1.6475, 7.1042, 1.6475, 7.3333, 0.7784, 7.3381]}], 'spans': [{'offset': 1839, 'length': 2}], 'elements': ['/paragraphs/19']}, {'rowIndex': 3, 'columnIndex': 1, 'content': '5.6', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6475, 7.1042, 2.211, 7.1042, 2.211, 7.3333, 1.6475, 7.3333]}], 'spans': [{'offset': 1844, 'length': 3}], 'elements': ['/paragraphs/20']}, {'rowIndex': 3, 'columnIndex': 2, 'content': '5.3', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 7.1042, 2.7124, 7.1042, 2.7124, 7.3333, 2.211, 7.3333 ...
#  {'pageNumber': 2,
#   'identifier': '61670436',
#   'type': 'table',
#   'objectContent': {'rowCount': 3, 'columnCount': 5, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': '', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.3312, 4.5977, 5.4677, 4.5977, 5.4629, 4.8984, 4.3312, 4.8984]}], 'spans': []}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': '2019', 'boundingRegions': [{'pageNumber': 2, 'polygon': [5.4677, 4.5977, 5.993, 4.5977, 5.9882, 4.8984, 5.4629, 4.8984]}], 'spans': [{'offset': 7900, 'length': 4}], 'elements': ['/paragraphs/187']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': '2020', 'boundingRegions': [{'pageNumber': 2, 'polygon': [5.993, 4.5977, 6.5851, 4.5977, 6.5851, 4.8984, 5.9882, 4.8984]}], 'spans': [{'offset': 7907, 'length': 4}], 'elements': ['/paragraphs/188']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': '2021', 'boundingRegions': [{'pageNumber': 2, 'polygon': [6.5851, 4.5977, 7.1295, 4.5977, 7.1295, 4.8984, 6.5851, 4.8984]}], 'spans': [{'offset': 7914, 'length': 4}], 'elements': ['/paragraphs/189']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': '2022', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.1295, 4.5977, 7.6691, 4.5977, 7.6691, 4.8984, 7.1295, 4.8984]}], 'spans': [{'offset': 7921, 'length': 4}], 'elements': ['/paragraphs/190']}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'Structures Burned', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.3312, 4.8984, 5.4629, 4.8984, 5.4629, 5.1276, 4.3312, 5.1276]}], 'spans': [{'offset': 7952, 'length': 17}], 'elements': ['/paragraphs/191']}, {'rowIndex': 1, 'columnIndex': 1, 'content': '963', 'boundingRegions': [{'pageNumber': 2, 'polygon': [5.4629, 4.8984, 5.9882, 4.8984, 5.9882, 5.1276, 5.4629, 5.1276]}], 'spans': [{'offset': 7972, 'length': 3}], 'elements': ['/paragraphs/192']}, {'rowIndex': 1, 'columnIndex': 2, 'content': '17,904', 'boundingRegions': [{'pageNumber': 2, 'polygon': [5.9882, 4.8984, 6.5851, 4.8984, 6.5851, 5.1276, 5.9882, 5.1276]}], 'spans': [{'offset': 7978, 'length': 6}], 'elements': ['/paragraphs/193']}, {'rowIndex': 1, 'columnIndex': 3, 'content': '5,972', 'boundingRegions': [{'pageNumber': 2, 'polygon': [6.5851, 4.8984, 7.1295, 4.8984, 7.1295, 5.1276, 6.5851, 5.1276]}], 'spans': [{'offset': 7987, 'length': 5}], 'elements': ['/paragraphs/194']}, {'rowIndex': 1, 'columnIndex': 4, 'content': '2,717', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.1295, 4.8984, 7.6691, 4.8984, 7.6691, 5.1276, 7.1295, 5.1276]}], 'spans': [{'offset': 7995, 'length': 5}], 'elements': ['/paragraphs/195']}, {'rowIndex': 2, 'columnIndex': 0, 'content': '% Residences', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.3312, 5.1276, 5.4629, 5.1276, 5.4629, 5.3711, 4.3312, 5.3711]}], 'spans': [{'offset': 8005, 'length': 12}], 'elements': ['/paragraphs/196']}, {'rowIndex': 2, 'columnIndex': 1, 'content': '46%', 'boundingRegions': [{'pageNumber': 2, 'polygon': [5.4629, 5.1276, 5.9882, 5.1276, 5.9882, 5.3663, 5.4629, 5.3711]}], 'spans': [{'offset': 8020, 'length': 3}], 'elements': ['/paragraphs/197']}, {'rowIndex': 2, 'columnIndex': 2, 'content': '54%', 'boundingRegions': [{'pageNumber': 2, 'polygon': [5.9882, 5.1276, 6.5851, 5.1276, 6.5851, 5.3663, 5.9882, 5.3663]}], 'spans': [{'offset': 8026, 'length': 3}], 'elements': ['/paragraphs/198']}, {'rowIndex': 2, 'columnIndex': 3, 'content': '60%', 'boundingRegions': [{'pageNumber': 2, 'polygon': [6.5851, 5.1276, 7.1295, 5.1276, 7.1295, 5.3711, 6.5851, 5.3663]}], 'spans': [{'offset': 8032, 'length': 3}], 'elements': ['/paragraphs/199']}, {'rowIndex': 2, 'columnIndex': 4, 'content': '46%', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.1295, 5.1276, 7.6691, 5.1276, 7.6643, 5.3711, 7.1295, 5.3711]}], 'spans': [{'offset': 8038, 'length': 3}], 'elements': ['/paragraphs/200']}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.3312, 4.4162, 5.7643, 4.421, 5.7638, 4.569, 4.3307, 4.5642]}, {'pageNumber': 2, 'polygon': [4.3354, 4.5988, 7.7025, 4.61 ...
#  {'pageNumber': 1,
#   'identifier': '65837635',
#   'type': 'figure',
#   'objectContent': 'The image appears to include a graphical header associated with the Congressional Research Service (CRS). Here is a description of the components visible in the image:\n\n1. **Logo & Text**:\n   - On the left side, there is a stylized logo featuring a simplified graphic of a dome, symbolizing the United States Capitol.\n   - Below the logo is the text: "Congressional Research Service."\n   - Beneath this line, there is additional text stating: "Informing the legislative debate since 1914."\n\n2. **Title**:\n   - On the right side, there is a blue box with the text: "IN FOCUS."\n\nThere are no visible images, graphs, or coordinate systems in the provided image. It is limited to a header or a title graphic most likely for a report or publication. The image lacks any data visualizations or detailed elements involving axes or values.'},
#  {'pageNumber': 1,
#   'identifier': '53267882',
#   'type': 'figure',
#   'objectContent': 'The provided image is a combination line and area graph that compares the number of fires and the total area burned from 1993 to 2022. \n\n### Axes:\n- **Horizontal Axis (X-Axis):** Displays the years from 1993 to 2022, marked in 5-year increments.\n- **Left Vertical Axis (Y-Axis):** Measures the number of fires in thousands, ranging from 0 to 120 in increments of 20.\n- **Right Vertical Axis (Y-Axis, secondary):** Measures the area burned in millions of acres, ranging from 0 to 12 in increments of 2.\n\n### Graph Components:\n1. **Red Line (with circles at data points):** Represents the number of fires each year. The line appears to fluctuate between approximately 60,000 and 100,000 fires per year, with notable peaks around the late 1990s and early 2010s.\n2. **Grey Shaded Area:** Represents the acres burned each year. The shaded area also fluctuates annually, with several peaks and troughs. Peaks in the shaded area seem to correlate with data points on the red line, but not perfectly.\n\n### Key Data Points:\n- In 1993, the number of fires was around 75,000, and the acres burned were about 2 million.\n- Around 2000, there was a peak with over 90,000 fires and about 8 million acres burned.\n- In 2020, the number of fires was just below 60,000, and the acres burned were around 10 million.\n- By 2022, the number of fires was approximately 65,000, and the acres burned was around 7 million.\n\nThe vertical dashed lines along the X-axis provide visual cues to match the data points for each year easily. The use of both line and area graphs helps to compare these two different but related metrics effectively over the given time period.'},
#  {'pageNumber': 1,
#   'identifier': '19835683',
#   'type': 'figure',
#   'objectContent': 'The provided image is a bar chart that provides information about wildfires in the U.S. in various years, specifically the acres burned and the number of fires.\n\nDetails from the image:\n\n1. **Axes and Labels:**\n   - The x-axis shows the "Acres burned (millions)".\n   - The y-axis lists the years.\n\n2. **Years and Acres Burned:**\n   - **2015:** 10.13 million acres\n   - **2020:** 10.12 million acres\n   - **2017:** 10.03 million acres\n   - **2006:** 9.87 million acres\n   - **2007:** 9.33 million acres\n\n3. **Number of Fires:**\n   - **2015:** 68.2 (represented in an orange circle)\n   - **2020:** 59.0 (represented in an orange circle)\n   - **2017:** 71.5 (represented in an orange circle)\n   - **2006:** 96.4 (represented in an orange circle)\n   - **2007:** 67.8 (represented in an orange circle)\n\nThe bars represent the acres burned in millions for each given year and are shaded in gray. The numeric values for acres burned are displayed inside or beside the bars, and the number of fires is represented within orange circles next to each year.'},
#  {'pageNumber': 2,
#   'identifier': '634444',
#   'type': 'figure',
#   'objectContent': 'The image is a stacked bar chart illustrating the distribution of some categories over the years from 2018 to 2022. The y-axis represents percentage values ranging from 0% to 100%, and the x-axis represents the years 2018 through 2022.\n\nThe chart consists of bars for each year broken down into four components, each represented by a different color:\n\n- Non-federal (top portion, light purple)\n- Other federal (second from top, darker purple)\n- DOI (second from bottom, light brownish-green)\n- Forest Service (bottom portion, dark blue)\n\nHere is a detailed breakdown of the distribution for each year:\n\n- **2018:**\n  - Non-federal: Approximately 64%\n  - Other federal: Approximately 15%\n  - DOI: Approximately 21%\n  - Forest Service: Approximately 25%\n  \n- **2019:**\n  - Non-federal: Approximately 84%\n  - Other federal: Less than 5%\n  - DOI: Approximately 10%\n  - Forest Service: Approximately 12%\n\n- **2020:**\n  - Non-federal: Approximately 64%\n  - Other federal: Less than 5%\n  - DOI: Approximately 36%\n  - Forest Service: Approximately 39%\n\n- **2021:**\n  - Non-federal: Approximately 64%\n  - Other federal: Less than 5%\n  - DOI: Approximately 36%\n  - Forest Service: Approximately 54%\n\n- **2022:**\n  - Non-federal: Approximately 64%\n  - Other federal: 12%\n  - DOI: Approximately 23%\n  - Forest Service: Approximately 25%\n\nEach color band within the bars represents one of the categories, and the total of these bands for any given year equals 100%. The chart provides a visual representation of the changing proportions of these four categories over time.'},
#  {'pageNumber': 2,
#   'identifier': '31358356',
#   'type': 'figure',
#   'objectContent': 'The image contains a bar chart: \n\nTitle or label: "Acres burned, millions"\n\n**Axes:**\n- Y-axis: "Acres burned, millions" with values marked at 0, 2, 4, 6, 8, 10, and 12.\n- X-axis: Years labeled from 2018 to 2022.\n\n**Data representation:**\n- Each year from 2018 to 2022 is represented by a stacked bar, showing acres burned divided into four categories: \n  - West Federal\n  - West Nonfederal\n  - East Federal \n  - East Nonfederal\n\n**Legend:**\n- The bars are segmented with colors representing:\n  - Dark red for "West Federal"\n  - Red-brown for "West Nonfederal"\n  - Beige for "East Federal"\n  - Light green for "East Nonfederal"\n\n**Detailed values from the bar chart:**\n\n**2018:**\n- West Federal: ~4 million acres\n- West Nonfederal: ~2.8 million acres\n- East Federal: ~1 million acres\n- East Nonfederal: ~1 million acres\n- Total: ~8.8 million acres\n\n**2019:**\n- West Federal: ~2 million acres\n- West Nonfederal: ~0.5 million acres\n- East Federal: ~1.5 million acres\n- East Nonfederal: ~0.7 million acres\n- Total: ~4.7 million acres\n\n**2020:**\n- West Federal: ~5 million acres\n- West Nonfederal: ~2.8 million acres\n- East Federal: ~0.7 million acres\n- East Nonfederal: ~0.7 million acres\n- Total: ~9.2 million acres\n\n**2021:**\n- West Federal: ~3 million acres\n- West Nonfederal: ~2 million acres \n- East Federal: ~1.5 million acres \n- East Nonfederal: ~0.7 million acres \n- Total: ~7.2 million acres\n\n**2022:**\n- West Federal: ~3 million acres\n- West Nonfederal: ~4.5 million acres\n- East Federal: ~1 million acres\n- East Nonfederal: ~0.5 million acres\n- Total: ~9 million acres'}]

# %% [markdown]
# ### assuming we do the orchestration here. could be semantik kernel, could be promtflow ...

# %%
prompt = "What is the change in wild fires from 1993 to 2022?"

# %%
# retrieve the chunks to answer the question.
result_content_index = []
for page in content_index:
    if page['pageNumber'] == 1:
        result_content_index.append(page)
result_content_index
# Out:
# [{'pageNumber': 1,
#   'pageContent': '<!-- FigureContent="Congressional Research Service Informing the legislative debate since 1914" --> IN FOCUS Updated June 1, 2023 # Wildfire Statistics Wildfires are unplanned fires, including lightning-caused fires, unauthorized human-caused fires, and escaped fires from prescribed burn projects. States are responsible for responding to wildfires that begin on nonfederal (state, local, and private) lands, except for lands protected by federal agencies under cooperative agreements. The federal government is responsible for responding to wildfires that begin on federal lands. The Forest Service (FS)-within the U.S. Department of Agriculture-carries out wildfire management and response across the 193 million acres of the National Forest System (NFS). The Department of the Interior (DOI) manages wildfire response for more than 400 million acres of national parks, wildlife refuges and preserves, other public lands, and Indian reservations. Wildfire statistics help illustrate past U.S. wildfire activity. Nationwide data compiled by the National Interagency Coordination Center (NICC) indicate that the number of annual wildfires is variable but has decreased slightly over the last 30 years. The number of acres affected annually, while also variable, generally has increased (see Figure 1). Since 2000, an annual average of 70,025 wildfires have burned an annual average of 7.0 million acres. The acreage figure is more than double the average annual acreage burned in the 1990s (3.3 million acres), although a greater number of fires occurred annually in the 1990s on average (78,600). Table 1. Annual Wildfires and Acres Burned 2018 2019 2020 2021 2022 Number of Fires (thousands) Federal 12.5 10.9 14.4 14.0 11.7 FS 5.6 5.3 6.7 6.2 5.9 DOI 7.0 5.3 7.6 7.6 5.8 Other 0.1 0.2 <0.1 0.2 0.1 Nonfederal 45.6 39.6 44.6 45.0 57.2 Total 58.1 50.5 59.0 59.0 69.0 Acres Burned (millions) Federal 4.6 3.1 7.1 5.2 4.0 FS 2.3 0.6 4.8 4.1 1.9 DOI 2.3 2.3 2.3 1.0 2.1 Other <0.1 <0.1 <0.1 < 0. <0.1 Nonfederal 4.1 1.6 3.1 1.9 3.6 Total 8.8 4.7 10.1 7.1 7.6 Source: National Interagency Coordination Center (NICC) Wildland Fire Summary and Statistics annual reports. Notes: FS = Forest Service; DOI = Department of the Interior. Column totals may not sum precisely due to rounding. Figure 1. Annual Wildfires and Acres Burned, 1993-2022 <!-- FigureContent="Fires, thousands Acres burned, millions 120 12 100 Fires 10 80 8 60 6 40 4 20 Acres burned 2 0 1993- 1998- 2003. 2008- 2013 2018- 2022- 0" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Data reflect wildland fires and acres burned nationwide, including wildland fires on federal and nonfederal lands. From 2013 to 2022, there were an average of 61,410 wildfires annually and an average of 7.2 million acres impacted annually. In 2022, 68,988 wildfires burned 7.6 million acres. Over 40% of those acres were in Alaska (3.1 million acres). As of June 1, 2023, around 18,300 wildfires have impacted over 511,000 acres this year. Figure 2. Top Five Years with Largest Wildfire Acreage Burned Since 1960 <!-- FigureContent="Year Acres burned (millions) Number of Fires 2015 10.13 68.2 2020 10.12 59.0 2017 10.03 71.5 2006 9.87 96.4 2007 9.33 67.8" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Number of fires in thousands. The number of fires and acreage burned are indicators of the annual level of wildfire activity. These numbers may not be indicative of fire\'s impact on human development or communities, since many fires occur in large, relatively undeveloped areas. Acreage burned also does not indicate the severity of a wildfire, the degree of impact upon forests or soils, or other ecological effects. Most wildfires are human-caused (89% of the average number of wildfires from 2018 to 2022). Wildfires caused by lightning tend to be slightly larger and to burn more acreage (53% of the average acreage burned from 2018 to 2022) than human-caused fires. <!-- P ...
#   'identifier': '36268147, 65837635, 53267882, 19835683'}]

# %%
result_object_index = []
for result in result_content_index:
    objectRefereces = result['identifier']
    if objectRefereces:
        objectRefereces = objectRefereces.split(', ')
        for object in totalObjectsInDocument:
            if object['identifier'] in objectRefereces:
                result_object_index.append(object)
result_object_index
# Out:
# [{'pageNumber': 1,
#   'identifier': '36268147',
#   'type': 'table',
#   'objectContent': {'rowCount': 15, 'columnCount': 6, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.3451, 1.6522, 6.3451, 1.6522, 6.6506, 0.7784, 6.6506]}], 'spans': []}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': '2018', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6522, 6.3451, 2.211, 6.3451, 2.211, 6.6506, 1.6522, 6.6506]}], 'spans': [{'offset': 1692, 'length': 4}], 'elements': ['/paragraphs/7']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': '2019', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 6.3451, 2.7124, 6.3451, 2.7124, 6.6506, 2.211, 6.6506]}], 'spans': [{'offset': 1699, 'length': 4}], 'elements': ['/paragraphs/8']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': '2020', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7124, 6.3451, 3.209, 6.3451, 3.209, 6.6506, 2.7124, 6.6506]}], 'spans': [{'offset': 1706, 'length': 4}], 'elements': ['/paragraphs/9']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': '2021', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.209, 6.3451, 3.6817, 6.3451, 3.6817, 6.6506, 3.209, 6.6506]}], 'spans': [{'offset': 1713, 'length': 4}], 'elements': ['/paragraphs/10']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 5, 'content': '2022', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.6817, 6.3451, 4.1354, 6.3451, 4.1354, 6.6554, 3.6817, 6.6506]}], 'spans': [{'offset': 1720, 'length': 4}], 'elements': ['/paragraphs/11']}, {'rowIndex': 1, 'columnIndex': 0, 'columnSpan': 6, 'content': 'Number of Fires (thousands)', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.6506, 4.1354, 6.6554, 4.1354, 6.8845, 0.7784, 6.8845]}], 'spans': [{'offset': 1755, 'length': 27}], 'elements': ['/paragraphs/12']}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Federal', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.8845, 1.6522, 6.8845, 1.6475, 7.1042, 0.7784, 7.1089]}], 'spans': [{'offset': 1792, 'length': 7}], 'elements': ['/paragraphs/13']}, {'rowIndex': 2, 'columnIndex': 1, 'content': '12.5', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6522, 6.8845, 2.211, 6.8845, 2.211, 7.1042, 1.6475, 7.1042]}], 'spans': [{'offset': 1802, 'length': 4}], 'elements': ['/paragraphs/14']}, {'rowIndex': 2, 'columnIndex': 2, 'content': '10.9', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 6.8845, 2.7124, 6.8845, 2.7124, 7.1042, 2.211, 7.1042]}], 'spans': [{'offset': 1809, 'length': 4}], 'elements': ['/paragraphs/15']}, {'rowIndex': 2, 'columnIndex': 3, 'content': '14.4', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7124, 6.8845, 3.209, 6.8845, 3.209, 7.1042, 2.7124, 7.1042]}], 'spans': [{'offset': 1816, 'length': 4}], 'elements': ['/paragraphs/16']}, {'rowIndex': 2, 'columnIndex': 4, 'content': '14.0', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.209, 6.8845, 3.6817, 6.8845, 3.6817, 7.1042, 3.209, 7.1042]}], 'spans': [{'offset': 1823, 'length': 4}], 'elements': ['/paragraphs/17']}, {'rowIndex': 2, 'columnIndex': 5, 'content': '11.7', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.6817, 6.8845, 4.1354, 6.8845, 4.1354, 7.1042, 3.6817, 7.1042]}], 'spans': [{'offset': 1830, 'length': 4}], 'elements': ['/paragraphs/18']}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'FS', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 7.1089, 1.6475, 7.1042, 1.6475, 7.3333, 0.7784, 7.3381]}], 'spans': [{'offset': 1839, 'length': 2}], 'elements': ['/paragraphs/19']}, {'rowIndex': 3, 'columnIndex': 1, 'content': '5.6', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6475, 7.1042, 2.211, 7.1042, 2.211, 7.3333, 1.6475, 7.3333]}], 'spans': [{'offset': 1844, 'length': 3}], 'elements': ['/paragraphs/20']}, {'rowIndex': 3, 'columnIndex': 2, 'content': '5.3', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 7.1042, 2.7124, 7.1042, 2.7124, 7.3333, 2.211, 7.3333 ...
#  {'pageNumber': 1,
#   'identifier': '65837635',
#   'type': 'figure',
#   'objectContent': 'The image appears to include a graphical header associated with the Congressional Research Service (CRS). Here is a description of the components visible in the image:\n\n1. **Logo & Text**:\n   - On the left side, there is a stylized logo featuring a simplified graphic of a dome, symbolizing the United States Capitol.\n   - Below the logo is the text: "Congressional Research Service."\n   - Beneath this line, there is additional text stating: "Informing the legislative debate since 1914."\n\n2. **Title**:\n   - On the right side, there is a blue box with the text: "IN FOCUS."\n\nThere are no visible images, graphs, or coordinate systems in the provided image. It is limited to a header or a title graphic most likely for a report or publication. The image lacks any data visualizations or detailed elements involving axes or values.'},
#  {'pageNumber': 1,
#   'identifier': '53267882',
#   'type': 'figure',
#   'objectContent': 'The provided image is a combination line and area graph that compares the number of fires and the total area burned from 1993 to 2022. \n\n### Axes:\n- **Horizontal Axis (X-Axis):** Displays the years from 1993 to 2022, marked in 5-year increments.\n- **Left Vertical Axis (Y-Axis):** Measures the number of fires in thousands, ranging from 0 to 120 in increments of 20.\n- **Right Vertical Axis (Y-Axis, secondary):** Measures the area burned in millions of acres, ranging from 0 to 12 in increments of 2.\n\n### Graph Components:\n1. **Red Line (with circles at data points):** Represents the number of fires each year. The line appears to fluctuate between approximately 60,000 and 100,000 fires per year, with notable peaks around the late 1990s and early 2010s.\n2. **Grey Shaded Area:** Represents the acres burned each year. The shaded area also fluctuates annually, with several peaks and troughs. Peaks in the shaded area seem to correlate with data points on the red line, but not perfectly.\n\n### Key Data Points:\n- In 1993, the number of fires was around 75,000, and the acres burned were about 2 million.\n- Around 2000, there was a peak with over 90,000 fires and about 8 million acres burned.\n- In 2020, the number of fires was just below 60,000, and the acres burned were around 10 million.\n- By 2022, the number of fires was approximately 65,000, and the acres burned was around 7 million.\n\nThe vertical dashed lines along the X-axis provide visual cues to match the data points for each year easily. The use of both line and area graphs helps to compare these two different but related metrics effectively over the given time period.'},
#  {'pageNumber': 1,
#   'identifier': '19835683',
#   'type': 'figure',
#   'objectContent': 'The provided image is a bar chart that provides information about wildfires in the U.S. in various years, specifically the acres burned and the number of fires.\n\nDetails from the image:\n\n1. **Axes and Labels:**\n   - The x-axis shows the "Acres burned (millions)".\n   - The y-axis lists the years.\n\n2. **Years and Acres Burned:**\n   - **2015:** 10.13 million acres\n   - **2020:** 10.12 million acres\n   - **2017:** 10.03 million acres\n   - **2006:** 9.87 million acres\n   - **2007:** 9.33 million acres\n\n3. **Number of Fires:**\n   - **2015:** 68.2 (represented in an orange circle)\n   - **2020:** 59.0 (represented in an orange circle)\n   - **2017:** 71.5 (represented in an orange circle)\n   - **2006:** 96.4 (represented in an orange circle)\n   - **2007:** 67.8 (represented in an orange circle)\n\nThe bars represent the acres burned in millions for each given year and are shaded in gray. The numeric values for acres burned are displayed inside or beside the bars, and the number of fires is represented within orange circles next to each year.'}]

# %%
### generate system message
system_message = []
for result in result_object_index:
        system_message.append(result['objectContent'])

# %%
system_message = system_message + result_content_index
system_message
# Out:
# [{'rowCount': 15, 'columnCount': 6, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': '', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.3451, 1.6522, 6.3451, 1.6522, 6.6506, 0.7784, 6.6506]}], 'spans': []}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': '2018', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6522, 6.3451, 2.211, 6.3451, 2.211, 6.6506, 1.6522, 6.6506]}], 'spans': [{'offset': 1692, 'length': 4}], 'elements': ['/paragraphs/7']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': '2019', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 6.3451, 2.7124, 6.3451, 2.7124, 6.6506, 2.211, 6.6506]}], 'spans': [{'offset': 1699, 'length': 4}], 'elements': ['/paragraphs/8']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': '2020', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7124, 6.3451, 3.209, 6.3451, 3.209, 6.6506, 2.7124, 6.6506]}], 'spans': [{'offset': 1706, 'length': 4}], 'elements': ['/paragraphs/9']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': '2021', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.209, 6.3451, 3.6817, 6.3451, 3.6817, 6.6506, 3.209, 6.6506]}], 'spans': [{'offset': 1713, 'length': 4}], 'elements': ['/paragraphs/10']}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 5, 'content': '2022', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.6817, 6.3451, 4.1354, 6.3451, 4.1354, 6.6554, 3.6817, 6.6506]}], 'spans': [{'offset': 1720, 'length': 4}], 'elements': ['/paragraphs/11']}, {'rowIndex': 1, 'columnIndex': 0, 'columnSpan': 6, 'content': 'Number of Fires (thousands)', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.6506, 4.1354, 6.6554, 4.1354, 6.8845, 0.7784, 6.8845]}], 'spans': [{'offset': 1755, 'length': 27}], 'elements': ['/paragraphs/12']}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Federal', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 6.8845, 1.6522, 6.8845, 1.6475, 7.1042, 0.7784, 7.1089]}], 'spans': [{'offset': 1792, 'length': 7}], 'elements': ['/paragraphs/13']}, {'rowIndex': 2, 'columnIndex': 1, 'content': '12.5', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6522, 6.8845, 2.211, 6.8845, 2.211, 7.1042, 1.6475, 7.1042]}], 'spans': [{'offset': 1802, 'length': 4}], 'elements': ['/paragraphs/14']}, {'rowIndex': 2, 'columnIndex': 2, 'content': '10.9', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 6.8845, 2.7124, 6.8845, 2.7124, 7.1042, 2.211, 7.1042]}], 'spans': [{'offset': 1809, 'length': 4}], 'elements': ['/paragraphs/15']}, {'rowIndex': 2, 'columnIndex': 3, 'content': '14.4', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.7124, 6.8845, 3.209, 6.8845, 3.209, 7.1042, 2.7124, 7.1042]}], 'spans': [{'offset': 1816, 'length': 4}], 'elements': ['/paragraphs/16']}, {'rowIndex': 2, 'columnIndex': 4, 'content': '14.0', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.209, 6.8845, 3.6817, 6.8845, 3.6817, 7.1042, 3.209, 7.1042]}], 'spans': [{'offset': 1823, 'length': 4}], 'elements': ['/paragraphs/17']}, {'rowIndex': 2, 'columnIndex': 5, 'content': '11.7', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.6817, 6.8845, 4.1354, 6.8845, 4.1354, 7.1042, 3.6817, 7.1042]}], 'spans': [{'offset': 1830, 'length': 4}], 'elements': ['/paragraphs/18']}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'FS', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.7784, 7.1089, 1.6475, 7.1042, 1.6475, 7.3333, 0.7784, 7.3381]}], 'spans': [{'offset': 1839, 'length': 2}], 'elements': ['/paragraphs/19']}, {'rowIndex': 3, 'columnIndex': 1, 'content': '5.6', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.6475, 7.1042, 2.211, 7.1042, 2.211, 7.3333, 1.6475, 7.3333]}], 'spans': [{'offset': 1844, 'length': 3}], 'elements': ['/paragraphs/20']}, {'rowIndex': 3, 'columnIndex': 2, 'content': '5.3', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.211, 7.1042, 2.7124, 7.1042, 2.7124, 7.3333, 2.211, 7.3333]}], 'spans': [{'o ...
#  'The image appears to include a graphical header associated with the Congressional Research Service (CRS). Here is a description of the components visible in the image:\n\n1. **Logo & Text**:\n   - On the left side, there is a stylized logo featuring a simplified graphic of a dome, symbolizing the United States Capitol.\n   - Below the logo is the text: "Congressional Research Service."\n   - Beneath this line, there is additional text stating: "Informing the legislative debate since 1914."\n\n2. **Title**:\n   - On the right side, there is a blue box with the text: "IN FOCUS."\n\nThere are no visible images, graphs, or coordinate systems in the provided image. It is limited to a header or a title graphic most likely for a report or publication. The image lacks any data visualizations or detailed elements involving axes or values.',
#  'The provided image is a combination line and area graph that compares the number of fires and the total area burned from 1993 to 2022. \n\n### Axes:\n- **Horizontal Axis (X-Axis):** Displays the years from 1993 to 2022, marked in 5-year increments.\n- **Left Vertical Axis (Y-Axis):** Measures the number of fires in thousands, ranging from 0 to 120 in increments of 20.\n- **Right Vertical Axis (Y-Axis, secondary):** Measures the area burned in millions of acres, ranging from 0 to 12 in increments of 2.\n\n### Graph Components:\n1. **Red Line (with circles at data points):** Represents the number of fires each year. The line appears to fluctuate between approximately 60,000 and 100,000 fires per year, with notable peaks around the late 1990s and early 2010s.\n2. **Grey Shaded Area:** Represents the acres burned each year. The shaded area also fluctuates annually, with several peaks and troughs. Peaks in the shaded area seem to correlate with data points on the red line, but not perfectly.\n\n### Key Data Points:\n- In 1993, the number of fires was around 75,000, and the acres burned were about 2 million.\n- Around 2000, there was a peak with over 90,000 fires and about 8 million acres burned.\n- In 2020, the number of fires was just below 60,000, and the acres burned were around 10 million.\n- By 2022, the number of fires was approximately 65,000, and the acres burned was around 7 million.\n\nThe vertical dashed lines along the X-axis provide visual cues to match the data points for each year easily. The use of both line and area graphs helps to compare these two different but related metrics effectively over the given time period.',
#  'The provided image is a bar chart that provides information about wildfires in the U.S. in various years, specifically the acres burned and the number of fires.\n\nDetails from the image:\n\n1. **Axes and Labels:**\n   - The x-axis shows the "Acres burned (millions)".\n   - The y-axis lists the years.\n\n2. **Years and Acres Burned:**\n   - **2015:** 10.13 million acres\n   - **2020:** 10.12 million acres\n   - **2017:** 10.03 million acres\n   - **2006:** 9.87 million acres\n   - **2007:** 9.33 million acres\n\n3. **Number of Fires:**\n   - **2015:** 68.2 (represented in an orange circle)\n   - **2020:** 59.0 (represented in an orange circle)\n   - **2017:** 71.5 (represented in an orange circle)\n   - **2006:** 96.4 (represented in an orange circle)\n   - **2007:** 67.8 (represented in an orange circle)\n\nThe bars represent the acres burned in millions for each given year and are shaded in gray. The numeric values for acres burned are displayed inside or beside the bars, and the number of fires is represented within orange circles next to each year.',
#  {'pageNumber': 1,
#   'pageContent': '<!-- FigureContent="Congressional Research Service Informing the legislative debate since 1914" --> IN FOCUS Updated June 1, 2023 # Wildfire Statistics Wildfires are unplanned fires, including lightning-caused fires, unauthorized human-caused fires, and escaped fires from prescribed burn projects. States are responsible for responding to wildfires that begin on nonfederal (state, local, and private) lands, except for lands protected by federal agencies under cooperative agreements. The federal government is responsible for responding to wildfires that begin on federal lands. The Forest Service (FS)-within the U.S. Department of Agriculture-carries out wildfire management and response across the 193 million acres of the National Forest System (NFS). The Department of the Interior (DOI) manages wildfire response for more than 400 million acres of national parks, wildlife refuges and preserves, other public lands, and Indian reservations. Wildfire statistics help illustrate past U.S. wildfire activity. Nationwide data compiled by the National Interagency Coordination Center (NICC) indicate that the number of annual wildfires is variable but has decreased slightly over the last 30 years. The number of acres affected annually, while also variable, generally has increased (see Figure 1). Since 2000, an annual average of 70,025 wildfires have burned an annual average of 7.0 million acres. The acreage figure is more than double the average annual acreage burned in the 1990s (3.3 million acres), although a greater number of fires occurred annually in the 1990s on average (78,600). Table 1. Annual Wildfires and Acres Burned 2018 2019 2020 2021 2022 Number of Fires (thousands) Federal 12.5 10.9 14.4 14.0 11.7 FS 5.6 5.3 6.7 6.2 5.9 DOI 7.0 5.3 7.6 7.6 5.8 Other 0.1 0.2 <0.1 0.2 0.1 Nonfederal 45.6 39.6 44.6 45.0 57.2 Total 58.1 50.5 59.0 59.0 69.0 Acres Burned (millions) Federal 4.6 3.1 7.1 5.2 4.0 FS 2.3 0.6 4.8 4.1 1.9 DOI 2.3 2.3 2.3 1.0 2.1 Other <0.1 <0.1 <0.1 < 0. <0.1 Nonfederal 4.1 1.6 3.1 1.9 3.6 Total 8.8 4.7 10.1 7.1 7.6 Source: National Interagency Coordination Center (NICC) Wildland Fire Summary and Statistics annual reports. Notes: FS = Forest Service; DOI = Department of the Interior. Column totals may not sum precisely due to rounding. Figure 1. Annual Wildfires and Acres Burned, 1993-2022 <!-- FigureContent="Fires, thousands Acres burned, millions 120 12 100 Fires 10 80 8 60 6 40 4 20 Acres burned 2 0 1993- 1998- 2003. 2008- 2013 2018- 2022- 0" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Data reflect wildland fires and acres burned nationwide, including wildland fires on federal and nonfederal lands. From 2013 to 2022, there were an average of 61,410 wildfires annually and an average of 7.2 million acres impacted annually. In 2022, 68,988 wildfires burned 7.6 million acres. Over 40% of those acres were in Alaska (3.1 million acres). As of June 1, 2023, around 18,300 wildfires have impacted over 511,000 acres this year. Figure 2. Top Five Years with Largest Wildfire Acreage Burned Since 1960 <!-- FigureContent="Year Acres burned (millions) Number of Fires 2015 10.13 68.2 2020 10.12 59.0 2017 10.03 71.5 2006 9.87 96.4 2007 9.33 67.8" --> Source: NICC Wildland Fire Summary and Statistics annual reports. Note: Number of fires in thousands. The number of fires and acreage burned are indicators of the annual level of wildfire activity. These numbers may not be indicative of fire\'s impact on human development or communities, since many fires occur in large, relatively undeveloped areas. Acreage burned also does not indicate the severity of a wildfire, the degree of impact upon forests or soils, or other ecological effects. Most wildfires are human-caused (89% of the average number of wildfires from 2018 to 2022). Wildfires caused by lightning tend to be slightly larger and to burn more acreage (53% of the average acreage burned from 2018 to 2022) than human-caused fires. <!-- P ...
#   'identifier': '36268147, 65837635, 53267882, 19835683'}]

# %%
document_ask(prompt,system_message)
# Out:
# 'Based on the provided context and data, the change in the number of wildfires from 1993 to 2022 can be summarized as follows:\n\n- **In 1993:** The number of fires was approximately 75,000.\n- **In 2022:** The number of fires was approximately 65,000.\n\nSo, there is a decrease of about 10,000 wildfires from 1993 to 2022. This indicates that while the number of annual wildfires fluctuates, there has been a slight overall decrease over this period.'
